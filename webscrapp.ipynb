# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.sacnilk.com/entertainmenttopbar/Top_10_Indian_Movies_(India_Net_Collection)"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-HNL593YJ9N"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-HNL593YJ9N');
# </script>
# <script>
#   window._taboola = window._taboola || [];
#   _taboola.push({article:'auto'});
#   !function (e, f, u, i) {
#     if (!document.getElementById(i)){
#       e.async = 1;
#       e.src = u;
#       e.id = i;
#       f.parentNode.insertBefore(e, f);
#     }
#   }(document.createElement('script'),
#   document.getElementsByTagName('script')[0],
#   '//cdn.taboola.com/libtrc/sacnilk/loader.js',
#   'tb_loader_script');
#   if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
# </script>
# <script>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>Top 10 Indian Movies (India Net Collection) - Sacnilk</title>

# %%
print(title.text)
# Out:
# Top 10 Indian Movies (India Net Collection) - Sacnilk

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="table"><tr><th class="th">SN</th><th class="th">Movie (Release Year)</th><th class="th" title="Includes All Total Gross Collection,Overseas+India ">Worldwide</th><th class="th">India Net</th><th class="th">India Gross</th><th class="th">Overseas</th><th class="th">Budget</th><th class="th">Verdict</th></tr>
# <tr>
# <td class="td">1.</td>
# <td class="td"><a href="/movie/Baahubali_2_The_Conclusion">Baahubali 2  The Conclusion (2017)</a></td>
# <td class="td">1788.06</td>
# <td class="td" style="color:#337ab7">1030.42</td><td class="td">1416.9</td>
# <td class="td">371.16</td>
# <td class="td">250</td>
# <td class="td">All Time Blockbuster</td>
# </tr>
# <tr>
# <td class="td">2.</td>
# <td class="td"><a href="/movie/KGF_Chapter_2_2020">KGF Chapter 2 (2022)</a></td>
# <td class="td">1215</td>
# <td class="td" style="color:#337ab7">859.7</td><td class="td">1000.85</td>
# <td class="td">214.15</td>
# <td class="td">100</td>
# <td class="td">All Time Blockbuster</td>
# ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th class="th">SN</th>, <th class="th">Movie (Release Year)</th>, <th class="th" title="Includes All Total Gross Collection,Overseas+India ">Worldwide</th>, <th class="th">India Net</th>, <th class="th">India Gross</th>, <th class="th">Overseas</th>, <th class="th">Budget</th>, <th class="th">Verdict</th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['SN', 'Movie (Release Year)', 'Worldwide', 'India Net', 'India Gross', 'Overseas', 'Budget', 'Verdict']

# %%
import pandas as pd
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [SN, Movie (Release Year), Worldwide, India Net, India Gross, Overseas, Budget, Verdict]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
# Out:
# [<tr><th class="th">SN</th><th class="th">Movie (Release Year)</th><th class="th" title="Includes All Total Gross Collection,Overseas+India ">Worldwide</th><th class="th">India Net</th><th class="th">India Gross</th><th class="th">Overseas</th><th class="th">Budget</th><th class="th">Verdict</th></tr>, <tr>
# <td class="td">1.</td>
# <td class="td"><a href="/movie/Baahubali_2_The_Conclusion">Baahubali 2  The Conclusion (2017)</a></td>
# <td class="td">1788.06</td>
# <td class="td" style="color:#337ab7">1030.42</td><td class="td">1416.9</td>
# <td class="td">371.16</td>
# <td class="td">250</td>
# <td class="td">All Time Blockbuster</td>
# </tr>, <tr>
# <td class="td">2.</td>
# <td class="td"><a href="/movie/KGF_Chapter_2_2020">KGF Chapter 2 (2022)</a></td>
# <td class="td">1215</td>
# <td class="td" style="color:#337ab7">859.7</td><td class="td">1000.85</td>
# <td class="td">214.15</td>
# <td class="td">100</td>
# <td class="td">All Time Blockbuster</td>
# </tr>, <tr>
# ...

# %%
ind=0
for i in rows[1:6]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['1.', 'Baahubali 2  The Conclusion (2017)', '1788.06', '1030.42', '1416.9', '371.16', '250', 'All Time Blockbuster']
# ['2.', 'KGF Chapter 2 (2022)', '1215', '859.7', '1000.85', '214.15', '100', 'All Time Blockbuster']
# ['3.', 'RRR (2022)', '1230', '782.2', '915.85', '314.15', '550', 'Blockbuster']
# ['4.', 'Jawan (2023)', '1160', '640.25', '760', '400', '300', 'All Time Blockbuster']
# ['5.', 'Animal (2023)', '915', '553.87', '660', '255', '200', 'All Time Blockbuster']

# %%
df
# Out:
#    SN                Movie (Release Year) Worldwide India Net India Gross  \
# 0  1.  Baahubali 2  The Conclusion (2017)   1788.06   1030.42      1416.9
# 1  2.                KGF Chapter 2 (2022)      1215     859.7     1000.85
# 2  3.                          RRR (2022)      1230     782.2      915.85
# 3  4.                        Jawan (2023)      1160    640.25         760
# 4  5.                       Animal (2023)       915    553.87         660
#
#   Overseas Budget               Verdict
# 0   371.16    250  All Time Blockbuster
# 1   214.15    100  All Time Blockbuster
# 2   314.15    550           Blockbuster
# 3      400    300  All Time Blockbuster
# 4      255    200  All Time Blockbuster

# %%
df.to_csv("movies.csv")

# %%
p = requests.get(url)

# %%
code = BeautifulSoup(p.text,'html')
t = code.find('table')
print(t)
# Out:
# <table class="table"><tr><th class="th">SN</th><th class="th">Movie (Release Year)</th><th class="th" title="Includes All Total Gross Collection,Overseas+India ">Worldwide</th><th class="th">India Net</th><th class="th">India Gross</th><th class="th">Overseas</th><th class="th">Budget</th><th class="th">Verdict</th></tr>
# <tr>
# <td class="td">1.</td>
# <td class="td"><a href="/movie/Baahubali_2_The_Conclusion">Baahubali 2  The Conclusion (2017)</a></td>
# <td class="td">1788.06</td>
# <td class="td" style="color:#337ab7">1030.42</td><td class="td">1416.9</td>
# <td class="td">371.16</td>
# <td class="td">250</td>
# <td class="td">All Time Blockbuster</td>
# </tr>
# <tr>
# <td class="td">2.</td>
# <td class="td"><a href="/movie/KGF_Chapter_2_2020">KGF Chapter 2 (2022)</a></td>
# <td class="td">1215</td>
# <td class="td" style="color:#337ab7">859.7</td><td class="td">1000.85</td>
# <td class="td">214.15</td>
# <td class="td">100</td>
# <td class="td">All Time Blockbuster</td>
# ...

# %%
data = t.find_all('td')
print(data)
# Out:
# [<td class="td">1.</td>, <td class="td"><a href="/movie/Baahubali_2_The_Conclusion">Baahubali 2  The Conclusion (2017)</a></td>, <td class="td">1788.06</td>, <td class="td" style="color:#337ab7">1030.42</td>, <td class="td">1416.9</td>, <td class="td">371.16</td>, <td class="td">250</td>, <td class="td">All Time Blockbuster</td>, <td class="td">2.</td>, <td class="td"><a href="/movie/KGF_Chapter_2_2020">KGF Chapter 2 (2022)</a></td>, <td class="td">1215</td>, <td class="td" style="color:#337ab7">859.7</td>, <td class="td">1000.85</td>, <td class="td">214.15</td>, <td class="td">100</td>, <td class="td">All Time Blockbuster</td>, <td class="td">3.</td>, <td class="td"><a href="/movie/RRR_2020">RRR (2022)</a></td>, <td class="td">1230</td>, <td class="td" style="color:#337ab7">782.2</td>, <td class="td">915.85</td>, <td class="td">314.15</td>, <td class="td">550</td>, <td class="td">Blockbuster</td>, <td class="td">4.</td>, <td class="td"><a href="/movie/Jawan_2023">Jawan (2023)</a></t
# ...

# %%
data_act = [i.text for i in data]
print(data_act)
# Out:
# ['1.', 'Baahubali 2  The Conclusion (2017)', '1788.06', '1030.42', '1416.9', '371.16', '250', 'All Time Blockbuster', '2.', 'KGF Chapter 2 (2022)', '1215', '859.7', '1000.85', '214.15', '100', 'All Time Blockbuster', '3.', 'RRR (2022)', '1230', '782.2', '915.85', '314.15', '550', 'Blockbuster', '4.', 'Jawan (2023)', '1160', '640.25', '760', '400', '300', 'All Time Blockbuster', '5.', 'Animal (2023)', '915', '553.87', '660', '255', '200', 'All Time Blockbuster', '6.', 'Pathaan (2023)', '1055', '543.09', '657.5', '397.5', '250', 'All Time Blockbuster', '7.', 'Gadar 2 (2023)', '686', '525.7', '620.5', '65.5', '75', 'All Time Blockbuster', '8.', 'Baahubali (2015)', '650', '421', '516', '134', '180', 'Blockbuster', '9.', '2.0 (2018)', '744.78', '407.05', '551.5', '193.28', '543', 'Average', '10.', 'Salaar: Cease Fire - Part 1 (2023)', '617.75', '406.45', '487.75', '130', '200', 'Hit', '11.', 'Avatar: The Way of Water (2022)', '17380', '391.4', '477.5', '16902.5', '3200', 'Blockbuster', '1
# ...

# %%
newdf= pd.DataFrame(columns = ['Serial_no','M_name','WW','IN','IG','overall','Finance','Review'])

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [Serial_no, M_name, WW, IN, IG, overall, Finance, Review]
# Index: []

# %%
data_act[0:4]
print(len(data_act))
# Out:
# 160

# %%
ind = 0
st = 0
stop = 8
for i in data_act:
  if stop <= 160:
    newdf.loc[ind]= data_act[st:stop]
    st = st+8
    stop = stop+8
    ind = ind+1

# %%
newdf
# Out:
#    Serial_no                              M_name       WW       IN       IG  \
# 0         1.  Baahubali 2  The Conclusion (2017)  1788.06  1030.42   1416.9
# 1         2.                KGF Chapter 2 (2022)     1215    859.7  1000.85
# 2         3.                          RRR (2022)     1230    782.2   915.85
# 3         4.                        Jawan (2023)     1160   640.25      760
# 4         5.                       Animal (2023)      915   553.87      660
# 5         6.                      Pathaan (2023)     1055   543.09    657.5
# 6         7.                      Gadar 2 (2023)      686    525.7    620.5
# 7         8.                    Baahubali (2015)      650      421      516
# 8         9.                          2.0 (2018)   744.78   407.05    551.5
# 9        10.  Salaar: Cease Fire - Part 1 (2023)   617.75   406.45   487.75
# 10       11.     Avatar: The Way of Water (2022)    17380    391.4    477.5
# ...
